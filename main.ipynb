# %%
#Alex Netzley
#2/25/2024

#pat =
# !git clone https://{pat}@github.com/yashmanne/Fine_Active_Learning
# %cd Fine_Active_Learning

# %% [markdown]
# Main Code for Executing our Training

# %%
#Loading Relevant Libraries
# !pip install wandb -qU

import wandb

from train_logging import *

# %%
datasets = ['Flowers102']
num_samples = [1]
al_methods = ['SimpleRandom']
random_seeds = list(range(1))
hyperparameter_kwargs = {'max_runs':1, 'method':'grid', 'num_epochs':1}
run_all_combinations(datasets, num_samples, al_methods, random_seeds, hyperparameter_kwargs)
